# %%
Email = input("Enter Your Email = ")
Password = input("Enter your Password = ")
if Email=='talktomanishbhardwaj0010@gmail.com' and Password == 'boss@24' :
    print("Welcome")
elif Email == 'talktomanishbhardwaj0010@gmail.com' and Password != 'boss@24':
    print("Incorrect Password")
    Password = input("Enter your Password again!")
    if Password == 'boss@24':
        print("Welcome finally")
    else:
        print("Try again later")
else:
    print("Not correct")
# Out:
# Enter Your Email =  akjsgdkjsabd
# Enter your Password =  sfsad
# Not correct

# %% [markdown]
# Modules

# %%
import math

# %%
math.sqrt(6)
# Out:
# 2.449489742783178

# %%
math.pow(5,2)
# Out:
# 25.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.floor(3.6) #rounddown
# Out:
# 3

# %%
math.ceil(4.5) #roundup
# Out:
# 5

# %%
math.trunc(5.6)
# Out:
# 5

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(90)
# Out:
# -0.4480736161291701

# %%
math.sin(45)
# Out:
# 0.8509035245341184

# %%
round(math.sin(math.pi/2))
# Out:
# 1

# %%
round(math.sin(math.radians(60)))
# Out:
# 1

# %%
round(math.cos(math.radians(90)))
# Out:
# 0

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.nan
# Out:
# nan

# %%
math.inf
# Out:
# inf

# %%
math.fabs(-10)
# Out:
# 10.0

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.exp(5)
# Out:
# 148.4131591025766

# %%
import random

# %%
random.randint(1,6)
# Out:
# 3

# %%
random.randrange(3,9)
# Out:
# 3

# %%
random.random()
# Out:
# 0.789116289880726

# %%
ar = [1,2,3,4,5,6,7,8]
random.shuffle(ar)
ar
# Out:
# [3, 4, 1, 8, 2, 5, 7, 6]

# %%
random.uniform(3,9)
# Out:
# 3.7830604033488004

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2025-06-12 11:07:39.311763

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
