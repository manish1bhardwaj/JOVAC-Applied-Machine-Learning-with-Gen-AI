# %% [markdown]
# Arithmetic Operator

# %%
print(5+6)
print(5*6)
print(5%6)
print(5//6)
print(5/5)
# Out:
# 11
# 30
# 5
# 0
# 1.0

# %% [markdown]
# Relational or Comparision

# %%
print(5>6)
print(5<6)
print(5==6)
print(5>=5)
print(5<=6)
# Out:
# False
# True
# False
# True
# True

# %% [markdown]
# Logical Operators
